# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}
plt.rcParams['figure.figsize'] = 16,16

from scipy.ndimage.interpolation import zoom
from keras.preprocessing.image import load_img, img_to_array
from keras.applications.resnet_v2 import ResNet50V2
from keras.applications.resnet_v2 import preprocess_input
from keras.models import load_model

import tensorflow as tf
import numpy as np
import os
import logging

#PREVENT ERROR UNCESSARY MESSAGES
tf.get_logger().setLevel(logging.ERROR)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# Out:
# Using TensorFlow backend.

# %%
import gradcamutils

# %%
model = load_model('weights/Both_truncated/Both-Truncated_ResNet50V2.h5')
print("The ResNet50V2 Truncated Weights are Loaded")
# Out:
# The ResNet50V2 Truncated Weights are Loaded

# %%
model.summary()
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_bn (BatchNo (None, 56, 56, 64)   256         pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_relu (Activ (None, 56, 56, 64)   0           conv2_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4096        conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_pad (ZeroPadding (None, 58, 58, 64)   0           conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36864       conv2_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Add)          (None, 56, 56, 256)  0           conv2_block1_0_conv[0][0]
#                                                                  conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# GAP-resnet50v2 (GlobalAveragePo (None, 256)          0           conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# Dropout-resnet50v2 (Dropout)    (None, 256)          0           GAP-resnet50v2[0][0]
# __________________________________________________________________________________________________
# Softmax-resnet50v2 (Dense)      (None, 6)            1542        Dropout-resnet50v2[0][0]
# ==================================================================================================
# Total params: 86,022
# Trainable params: 85,638
# Non-trainable params: 384
# __________________________________________________________________________________________________

# %%
paths = ["CXR_normal.jpg"]

for path in paths:
    path = os.path.join("image",path)
    orig_img = np.array(load_img(path,target_size=(224,224)),dtype=np.uint8)
    img = np.array(load_img(path,target_size=(224,224)),dtype=np.float64)
    img = np.expand_dims(img,axis=0)
    img = preprocess_input(img)
    predictions = model.predict(img)
    
    gradcam=gradcamutils.grad_cam(model,img,layer_name='conv2_block1_3_conv')
    gradcamplus=gradcamutils.grad_cam_plus(model,img,layer_name='conv2_block1_out')
    print(path)
    fig, ax = plt.subplots(nrows=1,ncols=3)
    plt.subplot(131)
    plt.imshow(orig_img)
    plt.title("input image")
    plt.subplot(132)
    plt.imshow(orig_img)
    plt.imshow(gradcam,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM")
    plt.subplot(133)
    plt.imshow(orig_img)
    plt.imshow(gradcamplus,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM++")
    plt.tight_layout()
    plt.savefig("gradcam/Both_truncated/ResNet50V2/Truncated-ResNet50V2-CXR-Normal.tiff", 
                dpi=300, 
                bbox_inches=None, 
                frameon=None,
                pad_inches=0.0)
    plt.show()
# Out:
# image\CXR_normal.jpg

# %%
paths = ["CXR_covid19.jpg"]

for path in paths:
    path = os.path.join("image",path)
    orig_img = np.array(load_img(path,target_size=(224,224)),dtype=np.uint8)
    img = np.array(load_img(path,target_size=(224,224)),dtype=np.float64)
    img = np.expand_dims(img,axis=0)
    img = preprocess_input(img)
    predictions = model.predict(img)
    
    gradcam=gradcamutils.grad_cam(model,img,layer_name='conv2_block1_3_conv')
    gradcamplus=gradcamutils.grad_cam_plus(model,img,layer_name='conv2_block1_out')
    print(path)
    fig, ax = plt.subplots(nrows=1,ncols=3)
    plt.subplot(131)
    plt.imshow(orig_img)
    plt.title("input image")
    plt.subplot(132)
    plt.imshow(orig_img)
    plt.imshow(gradcam,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM")
    plt.subplot(133)
    plt.imshow(orig_img)
    plt.imshow(gradcamplus,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM++")
    plt.tight_layout()
    plt.savefig("gradcam/Both_truncated/ResNet50V2/Truncated-ResNet50V2-CXR-COVID19.tiff", 
                dpi=300, 
                bbox_inches=None, 
                frameon=None,
                pad_inches=0.0)
    plt.show()
# Out:
# image\CXR_covid19.jpg

# %%
paths = ["CXR_cap.jpg"]

for path in paths:
    path = os.path.join("image",path)
    orig_img = np.array(load_img(path,target_size=(224,224)),dtype=np.uint8)
    img = np.array(load_img(path,target_size=(224,224)),dtype=np.float64)
    img = np.expand_dims(img,axis=0)
    img = preprocess_input(img)
    predictions = model.predict(img)
    
    gradcam=gradcamutils.grad_cam(model,img,layer_name='conv2_block1_3_conv')
    gradcamplus=gradcamutils.grad_cam_plus(model,img,layer_name='conv2_block1_out')
    print(path)
    fig, ax = plt.subplots(nrows=1,ncols=3)
    plt.subplot(131)
    plt.imshow(orig_img)
    plt.title("input image")
    plt.subplot(132)
    plt.imshow(orig_img)
    plt.imshow(gradcam,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM")
    plt.subplot(133)
    plt.imshow(orig_img)
    plt.imshow(gradcamplus,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM++")
    plt.tight_layout()
    plt.savefig("gradcam/Both_truncated/ResNet50V2/Truncated-ResNet50V2-CXR-Pneumonia.tiff", 
                dpi=300, 
                bbox_inches=None, 
                frameon=None,
                pad_inches=0.0)
    plt.show()
# Out:
# image\CXR_cap.jpg

# %%
paths = ["CT_normal.jpg"]

for path in paths:
    path = os.path.join("image",path)
    orig_img = np.array(load_img(path,target_size=(224,224)),dtype=np.uint8)
    img = np.array(load_img(path,target_size=(224,224)),dtype=np.float64)
    img = np.expand_dims(img,axis=0)
    img = preprocess_input(img)
    predictions = model.predict(img)
    
    gradcam=gradcamutils.grad_cam(model,img,layer_name='conv2_block1_3_conv')
    gradcamplus=gradcamutils.grad_cam_plus(model,img,layer_name='conv2_block1_out')
    print(path)
    fig, ax = plt.subplots(nrows=1,ncols=3)
    plt.subplot(131)
    plt.imshow(orig_img)
    plt.title("input image")
    plt.subplot(132)
    plt.imshow(orig_img)
    plt.imshow(gradcam,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM")
    plt.subplot(133)
    plt.imshow(orig_img)
    plt.imshow(gradcamplus,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM++")
    plt.tight_layout()
    plt.savefig("gradcam/Both_truncated/ResNet50V2/Truncated-ResNet50V2-CT-Normal.tiff", 
                dpi=300, 
                bbox_inches=None, 
                frameon=None,
                pad_inches=0.0)
    plt.show()
# Out:
# image\CT_normal.jpg

# %%
paths = ["CT_covid19.png"]

for path in paths:
    path = os.path.join("image",path)
    orig_img = np.array(load_img(path,target_size=(224,224)),dtype=np.uint8)
    img = np.array(load_img(path,target_size=(224,224)),dtype=np.float64)
    img = np.expand_dims(img,axis=0)
    img = preprocess_input(img)
    predictions = model.predict(img)
    
    gradcam=gradcamutils.grad_cam(model,img,layer_name='conv2_block1_3_conv')
    gradcamplus=gradcamutils.grad_cam_plus(model,img,layer_name='conv2_block1_out')
    print(path)
    fig, ax = plt.subplots(nrows=1,ncols=3)
    plt.subplot(131)
    plt.imshow(orig_img)
    plt.title("input image")
    plt.subplot(132)
    plt.imshow(orig_img)
    plt.imshow(gradcam,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM")
    plt.subplot(133)
    plt.imshow(orig_img)
    plt.imshow(gradcamplus,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM++")
    plt.tight_layout()
    plt.savefig("gradcam/Both_truncated/ResNet50V2/Truncated-ResNet50V2-CT-COVID19.tiff", 
                dpi=300, 
                bbox_inches=None, 
                frameon=None,
                pad_inches=0.0)
    plt.show()
# Out:
# image\CT_covid19.png

# %%
paths = ["CT_cap.png"]

for path in paths:
    path = os.path.join("image",path)
    orig_img = np.array(load_img(path,target_size=(224,224)),dtype=np.uint8)
    img = np.array(load_img(path,target_size=(224,224)),dtype=np.float64)
    img = np.expand_dims(img,axis=0)
    img = preprocess_input(img)
    predictions = model.predict(img)
    
    gradcam=gradcamutils.grad_cam(model,img,layer_name='conv2_block1_3_conv')
    gradcamplus=gradcamutils.grad_cam_plus(model,img,layer_name='conv2_block1_out')
    print(path)
    fig, ax = plt.subplots(nrows=1,ncols=3)
    plt.subplot(131)
    plt.imshow(orig_img)
    plt.title("input image")
    plt.subplot(132)
    plt.imshow(orig_img)
    plt.imshow(gradcam,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM")
    plt.subplot(133)
    plt.imshow(orig_img)
    plt.imshow(gradcamplus,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM++")
    plt.tight_layout()
    plt.savefig("gradcam/Both_truncated/ResNet50V2/Truncated-ResNet50V2-CT-Pneumonia.tiff", 
                dpi=300, 
                bbox_inches=None, 
                frameon=None,
                pad_inches=0.0)
    plt.show()
# Out:
# image\CT_cap.png
