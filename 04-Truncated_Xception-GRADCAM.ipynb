# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}
plt.rcParams['figure.figsize'] = 16, 16

from scipy.ndimage.interpolation import zoom
from keras.preprocessing.image import load_img, img_to_array
from keras.applications.xception import Xception
from keras.applications.xception import preprocess_input
from keras.models import load_model

import tensorflow as tf
import numpy as np
import os
import logging

#PREVENT ERROR UNCESSARY MESSAGES
tf.get_logger().setLevel(logging.ERROR)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# Out:
# Using TensorFlow backend.

# %%
import gradcamutils2

# %%
model = load_model('weights/Both_truncated/Both-Truncated_Xception.h5')
print("The Xception Truncated Weights are Loaded")
# Out:
# The Xception Truncated Weights are Loaded

# %%
model.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 149, 149, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 149, 149, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 147, 147, 64) 18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 147, 147, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 147, 147, 64) 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 147, 147, 128 8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 147, 147, 128 0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 147, 147, 128 17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 74, 74, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 74, 74, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 74, 74, 128)  512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 74, 74, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# GAP-xception (GlobalAveragePool (None, 128)          0           add_1[0][0]
# __________________________________________________________________________________________________
# Dropout-xception (Dropout)      (None, 128)          0           GAP-xception[0][0]
# __________________________________________________________________________________________________
# Softmax-xception (Dense)        (None, 6)            774         Dropout-xception[0][0]
# ==================================================================================================
# Total params: 56,486
# Trainable params: 55,526
# Non-trainable params: 960
# __________________________________________________________________________________________________

# %%
paths = ["CXR_normal.jpg"]

for path in paths:
    path = os.path.join("image",path)
    orig_img = np.array(load_img(path,target_size=(299,299)),dtype=np.uint8)
    img = np.array(load_img(path,target_size=(299,299)),dtype=np.float64)
    img = np.expand_dims(img,axis=0)
    img = preprocess_input(img)
    predictions = model.predict(img)
    
    gradcam=gradcamutils2.grad_cam(model,img,layer_name='conv2d_1')
    gradcamplus=gradcamutils2.grad_cam_plus(model,img,layer_name='add_1')
    print(path)
    fig, ax = plt.subplots(nrows=1,ncols=3)
    plt.subplot(131)
    plt.imshow(orig_img)
    plt.title("input image")
    plt.subplot(132)
    plt.imshow(orig_img)
    plt.imshow(gradcam,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM")
    plt.subplot(133)
    plt.imshow(orig_img)
    plt.imshow(gradcamplus,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM++")
    plt.tight_layout()
    plt.savefig("gradcam/Both_truncated/Xception/Truncated-Xception-CXR-Normal.tiff", 
                dpi=300, 
                bbox_inches=None, 
                frameon=None,
                pad_inches=0.0)
    plt.show()
# Out:
# image\CXR_normal.jpg

# %%
paths = ["CXR_covid19.jpg"]

for path in paths:
    path = os.path.join("image",path)
    orig_img = np.array(load_img(path,target_size=(299,299)),dtype=np.uint8)
    img = np.array(load_img(path,target_size=(299,299)),dtype=np.float64)
    img = np.expand_dims(img,axis=0)
    img = preprocess_input(img)
    predictions = model.predict(img)
    
    gradcam=gradcamutils2.grad_cam(model,img,layer_name='conv2d_1')
    gradcamplus=gradcamutils2.grad_cam_plus(model,img,layer_name='add_1')
    print(path)
    fig, ax = plt.subplots(nrows=1,ncols=3)
    plt.subplot(131)
    plt.imshow(orig_img)
    plt.title("input image")
    plt.subplot(132)
    plt.imshow(orig_img)
    plt.imshow(gradcam,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM")
    plt.subplot(133)
    plt.imshow(orig_img)
    plt.imshow(gradcamplus,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM++")
    plt.tight_layout()
    plt.savefig("gradcam/Both_truncated/Xception/Truncated-Xception-CXR-COVID19.tiff", 
                dpi=300, 
                bbox_inches=None, 
                frameon=None,
                pad_inches=0.0)
    plt.show()
# Out:
# image\CXR_covid19.jpg

# %%
paths = ["CXR_cap.jpg"]

for path in paths:
    path = os.path.join("image",path)
    orig_img = np.array(load_img(path,target_size=(299,299)),dtype=np.uint8)
    img = np.array(load_img(path,target_size=(299,299)),dtype=np.float64)
    img = np.expand_dims(img,axis=0)
    img = preprocess_input(img)
    predictions = model.predict(img)
    
    gradcam=gradcamutils2.grad_cam(model,img,layer_name='conv2d_1')
    gradcamplus=gradcamutils2.grad_cam_plus(model,img,layer_name='add_1')
    print(path)
    fig, ax = plt.subplots(nrows=1,ncols=3)
    plt.subplot(131)
    plt.imshow(orig_img)
    plt.title("input image")
    plt.subplot(132)
    plt.imshow(orig_img)
    plt.imshow(gradcam,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM")
    plt.subplot(133)
    plt.imshow(orig_img)
    plt.imshow(gradcamplus,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM++")
    plt.tight_layout()
    plt.savefig("gradcam/Both_truncated/Xception/Truncated-Xception-CXR-Pneumonia.tiff", 
                dpi=300, 
                bbox_inches=None, 
                frameon=None,
                pad_inches=0.0)
    plt.show()
# Out:
# image\CXR_cap.jpg

# %%
paths = ["CT_normal.jpg"]

for path in paths:
    path = os.path.join("image",path)
    orig_img = np.array(load_img(path,target_size=(299,299)),dtype=np.uint8)
    img = np.array(load_img(path,target_size=(299,299)),dtype=np.float64)
    img = np.expand_dims(img,axis=0)
    img = preprocess_input(img)
    predictions = model.predict(img)
    
    gradcam=gradcamutils2.grad_cam(model,img,layer_name='conv2d_1')
    gradcamplus=gradcamutils2.grad_cam_plus(model,img,layer_name='add_1')
    print(path)
    fig, ax = plt.subplots(nrows=1,ncols=3)
    plt.subplot(131)
    plt.imshow(orig_img)
    plt.title("input image")
    plt.subplot(132)
    plt.imshow(orig_img)
    plt.imshow(gradcam,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM")
    plt.subplot(133)
    plt.imshow(orig_img)
    plt.imshow(gradcamplus,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM++")
    plt.tight_layout()
    plt.savefig("gradcam/Both_truncated/Xception/Truncated-Xception-CT-Normal.tiff", 
                dpi=300, 
                bbox_inches=None, 
                frameon=None,
                pad_inches=0.0)
    plt.show()
# Out:
# image\CT_normal.jpg

# %%
paths = ["CT_covid19.png"]

for path in paths:
    path = os.path.join("image",path)
    orig_img = np.array(load_img(path,target_size=(299,299)),dtype=np.uint8)
    img = np.array(load_img(path,target_size=(299,299)),dtype=np.float64)
    img = np.expand_dims(img,axis=0)
    img = preprocess_input(img)
    predictions = model.predict(img)
    
    gradcam=gradcamutils2.grad_cam(model,img,layer_name='conv2d_1')
    gradcamplus=gradcamutils2.grad_cam_plus(model,img,layer_name='add_1')
    print(path)
    fig, ax = plt.subplots(nrows=1,ncols=3)
    plt.subplot(131)
    plt.imshow(orig_img)
    plt.title("input image")
    plt.subplot(132)
    plt.imshow(orig_img)
    plt.imshow(gradcam,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM")
    plt.subplot(133)
    plt.imshow(orig_img)
    plt.imshow(gradcamplus,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM++")
    plt.tight_layout()
    plt.savefig("gradcam/Both_truncated/Xception/Truncated-Xception-CT-COVID19.tiff", 
                dpi=300, 
                bbox_inches=None, 
                frameon=None,
                pad_inches=0.0)
    plt.show()
# Out:
# image\CT_covid19.png

# %%
paths = ["CT_cap.png"]

for path in paths:
    path = os.path.join("image",path)
    orig_img = np.array(load_img(path,target_size=(299,299)),dtype=np.uint8)
    img = np.array(load_img(path,target_size=(299,299)),dtype=np.float64)
    img = np.expand_dims(img,axis=0)
    img = preprocess_input(img)
    predictions = model.predict(img)
    
    gradcam=gradcamutils2.grad_cam(model,img,layer_name='conv2d_1')
    gradcamplus=gradcamutils2.grad_cam_plus(model,img,layer_name='add_1')
    print(path)
    fig, ax = plt.subplots(nrows=1,ncols=3)
    plt.subplot(131)
    plt.imshow(orig_img)
    plt.title("input image")
    plt.subplot(132)
    plt.imshow(orig_img)
    plt.imshow(gradcam,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM")
    plt.subplot(133)
    plt.imshow(orig_img)
    plt.imshow(gradcamplus,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM++")
    plt.tight_layout()
    plt.savefig("gradcam/Both_truncated/Xception/Truncated-Xception-CT-Pneumonia.tiff", 
                dpi=300, 
                bbox_inches=None, 
                frameon=None,
                pad_inches=0.0)
    plt.show()
# Out:
# image\CT_cap.png
