# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}
plt.rcParams['figure.figsize'] = 16, 16

from scipy.ndimage.interpolation import zoom
from keras.preprocessing.image import load_img, img_to_array
import efficientnet.keras as efn 
from efficientnet.keras import preprocess_input
from keras.models import load_model

import tensorflow as tf
import numpy as np
import os
import logging

#PREVENT ERROR UNCESSARY MESSAGES
tf.get_logger().setLevel(logging.ERROR)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# Out:
# Using TensorFlow backend.

# %%
import gradcamutils

# %%
model = load_model('weights/Both_baselines/Both-Baseline_EfficientNetB0.h5')
print("The EfficientNet Baseline Weights are Loaded")
# Out:
# The EfficientNet Baseline Weights are Loaded

# %%
model.summary()
# Out:
# Model: "efficientnetb0"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 112, 112, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 112, 112, 32) 128         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 112, 112, 32) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# ...

# %%
paths = ["CXR_normal.jpg"]

for path in paths:
    path = os.path.join("image",path)
    orig_img = np.array(load_img(path,target_size=(224,224)),dtype=np.uint8)
    img = np.array(load_img(path,target_size=(224,224)),dtype=np.float64)
    img = np.expand_dims(img,axis=0)
    img = preprocess_input(img)
    predictions = model.predict(img)
    
    gradcam=gradcamutils.grad_cam(model,img,layer_name='top_conv')
    gradcamplus=gradcamutils.grad_cam_plus(model,img,layer_name='top_activation')
    print(path)
    fig, ax = plt.subplots(nrows=1,ncols=3)
    plt.subplot(131)
    plt.imshow(orig_img)
    plt.title("input image")
    plt.subplot(132)
    plt.imshow(orig_img)
    plt.imshow(gradcam,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM")
    plt.subplot(133)
    plt.imshow(orig_img)
    plt.imshow(gradcamplus,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM++")
    plt.tight_layout()
    plt.savefig("gradcam/Both_baselines/EfficientNetB0/Baseline-EfficientNetB0-CXR-Normal.tiff", 
                dpi=300, 
                bbox_inches=None, 
                frameon=None,
                pad_inches=0.0)
    plt.show()
# Out:
# image\CXR_normal.jpg

# %%
paths = ["CXR_covid19.jpg"]

for path in paths:
    path = os.path.join("image",path)
    orig_img = np.array(load_img(path,target_size=(224,224)),dtype=np.uint8)
    img = np.array(load_img(path,target_size=(224,224)),dtype=np.float64)
    img = np.expand_dims(img,axis=0)
    img = preprocess_input(img)
    predictions = model.predict(img)
    
    gradcam=gradcamutils.grad_cam(model,img,layer_name='top_conv')
    gradcamplus=gradcamutils.grad_cam_plus(model,img,layer_name='top_activation')
    print(path)
    fig, ax = plt.subplots(nrows=1,ncols=3)
    plt.subplot(131)
    plt.imshow(orig_img)
    plt.title("input image")
    plt.subplot(132)
    plt.imshow(orig_img)
    plt.imshow(gradcam,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM")
    plt.subplot(133)
    plt.imshow(orig_img)
    plt.imshow(gradcamplus,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM++")
    plt.tight_layout()
    plt.savefig("gradcam/Both_baselines/EfficientNetB0/Baseline-EfficientNetB0-CXR-COVID19.tiff", 
                dpi=300, 
                bbox_inches=None, 
                frameon=None,
                pad_inches=0.0)
    plt.show()
# Out:
# image\CXR_covid19.jpg

# %%
paths = ["CXR_cap.jpg"]

for path in paths:
    path = os.path.join("image",path)
    orig_img = np.array(load_img(path,target_size=(224,224)),dtype=np.uint8)
    img = np.array(load_img(path,target_size=(224,224)),dtype=np.float64)
    img = np.expand_dims(img,axis=0)
    img = preprocess_input(img)
    predictions = model.predict(img)
    
    gradcam=gradcamutils.grad_cam(model,img,layer_name='top_conv')
    gradcamplus=gradcamutils.grad_cam_plus(model,img,layer_name='top_activation')
    print(path)
    fig, ax = plt.subplots(nrows=1,ncols=3)
    plt.subplot(131)
    plt.imshow(orig_img)
    plt.title("input image")
    plt.subplot(132)
    plt.imshow(orig_img)
    plt.imshow(gradcam,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM")
    plt.subplot(133)
    plt.imshow(orig_img)
    plt.imshow(gradcamplus,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM++")
    plt.tight_layout()
    plt.savefig("gradcam/Both_baselines/EfficientNetB0/Baseline-EfficientNetB0-CXR-Pneumonia.tiff", 
                dpi=300, 
                bbox_inches=None, 
                frameon=None,
                pad_inches=0.0)
    plt.show()
# Out:
# image\CXR_cap.jpg

# %%
paths = ["CT_normal.jpg"]

for path in paths:
    path = os.path.join("image",path)
    orig_img = np.array(load_img(path,target_size=(224,224)),dtype=np.uint8)
    img = np.array(load_img(path,target_size=(224,224)),dtype=np.float64)
    img = np.expand_dims(img,axis=0)
    img = preprocess_input(img)
    predictions = model.predict(img)
    
    gradcam=gradcamutils.grad_cam(model,img,layer_name='top_conv')
    gradcamplus=gradcamutils.grad_cam_plus(model,img,layer_name='top_activation')
    print(path)
    fig, ax = plt.subplots(nrows=1,ncols=3)
    plt.subplot(131)
    plt.imshow(orig_img)
    plt.title("input image")
    plt.subplot(132)
    plt.imshow(orig_img)
    plt.imshow(gradcam,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM")
    plt.subplot(133)
    plt.imshow(orig_img)
    plt.imshow(gradcamplus,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM++")
    plt.tight_layout()
    plt.savefig("gradcam/Both_baselines/EfficientNetB0/Baseline-EfficientNetB0-CT-Normal.tiff", 
                dpi=300, 
                bbox_inches=None, 
                frameon=None,
                pad_inches=0.0)
    plt.show()
# Out:
# image\CT_normal.jpg

# %%
paths = ["CT_covid19.png"]

for path in paths:
    path = os.path.join("image",path)
    orig_img = np.array(load_img(path,target_size=(224,224)),dtype=np.uint8)
    img = np.array(load_img(path,target_size=(224,224)),dtype=np.float64)
    img = np.expand_dims(img,axis=0)
    img = preprocess_input(img)
    predictions = model.predict(img)
    
    gradcam=gradcamutils.grad_cam(model,img,layer_name='top_conv')
    gradcamplus=gradcamutils.grad_cam_plus(model,img,layer_name='top_activation')
    print(path)
    fig, ax = plt.subplots(nrows=1,ncols=3)
    plt.subplot(131)
    plt.imshow(orig_img)
    plt.title("input image")
    plt.subplot(132)
    plt.imshow(orig_img)
    plt.imshow(gradcam,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM")
    plt.subplot(133)
    plt.imshow(orig_img)
    plt.imshow(gradcamplus,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM++")
    plt.tight_layout()
    plt.savefig("gradcam/Both_baselines/EfficientNetB0/Baseline-EfficientNetB0-CT-COVID19.tiff", 
                dpi=300, 
                bbox_inches=None, 
                frameon=None,
                pad_inches=0.0)
    plt.show()
# Out:
# image\CT_covid19.png

# %%
paths = ["CT_cap.png"]

for path in paths:
    path = os.path.join("image",path)
    orig_img = np.array(load_img(path,target_size=(224,224)),dtype=np.uint8)
    img = np.array(load_img(path,target_size=(224,224)),dtype=np.float64)
    img = np.expand_dims(img,axis=0)
    img = preprocess_input(img)
    predictions = model.predict(img)
    
    gradcam=gradcamutils.grad_cam(model,img,layer_name='top_conv')
    gradcamplus=gradcamutils.grad_cam_plus(model,img,layer_name='top_activation')
    print(path)
    fig, ax = plt.subplots(nrows=1,ncols=3)
    plt.subplot(131)
    plt.imshow(orig_img)
    plt.title("input image")
    plt.subplot(132)
    plt.imshow(orig_img)
    plt.imshow(gradcam,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM")
    plt.subplot(133)
    plt.imshow(orig_img)
    plt.imshow(gradcamplus,alpha=0.4,cmap="jet")
    plt.title("Grad-CAM++")
    plt.tight_layout()
    plt.savefig("gradcam/Both_baselines/EfficientNetB0/Baseline-EfficientNetB0-CT-Pneumonia.tiff", 
                dpi=300, 
                bbox_inches=None, 
                frameon=None,
                pad_inches=0.0)
    plt.show()
# Out:
# image\CT_cap.png
